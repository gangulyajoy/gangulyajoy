# %% [markdown]
# <a href="https://colab.research.google.com/github/gangulyajoy/gangulyajoy/blob/main/HR%20Chatbot%20System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install llama_index
# Out:
# Requirement already satisfied: llama_index in /usr/local/lib/python3.13/dist-packages (0.14.24)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.24 in /usr/local/lib/python3.13/dist-packages (from llama_index) (0.14.24)
# Requirement already satisfied: llama-index-embeddings-openai<0.7,>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from llama_index) (0.6.0)
# Requirement already satisfied: llama-index-llms-openai<0.8,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from llama_index) (0.7.10)
# Requirement already satisfied: nltk>=3.9.3 in /usr/local/lib/python3.13/dist-packages (from llama_index) (3.10.3)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (3.14.3)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (2.5.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (2025.3.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (2.23.3)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (2.1.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (11.3.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (4.11.3)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (2.13.4)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (2.32.4)
# Requirement already satisfied: setuptools>=80.9.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (84.0.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.24->llama_index) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (9.1.4)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (0.14.0)
# Requirement already satisfied: tinytag>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (2.3.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (4.16.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15.0,>=0.14.24->llama_index) (2.3.0)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-embeddings-openai<0.7,>=0.6.0->llama_index) (2.54.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.13/dist-packages (from nltk>=3.9.3->llama_index) (0.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from nltk>=3.9.3->llama_index) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.13/dist-packages (from nltk>=3.9.3->llama_index) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.13/dist-packages (from nltk>=3.9.3->llama_index) (2025.11.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama_index) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama_index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama_index) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama_index) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama_index) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama_index) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama_index) (1.24.5)
# Requirement already satisfied: griffe in /usr/local/lib/python3.13/dist-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (2.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in /usr/local/lib/python3.13/dist-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (0.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama_index) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama_index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama_index) (0.16.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama_index) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx->llama-index-core<0.15.0,>=0.14.24->llama_index) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx->llama-index-core<0.15.0,>=0.14.24->llama_index) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx->llama-index-core<0.15.0,>=0.14.24->llama_index) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.15.0,>=0.14.24->llama_index) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.24->llama_index) (3.5.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.13/dist-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.24->llama_index) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.13/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15.0,>=0.14.24->llama_index) (26.3)
# Requirement already satisfied: griffecli==2.2.0 in /usr/local/lib/python3.13/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (2.2.0)
# Requirement already satisfied: griffelib==2.2.0 in /usr/local/lib/python3.13/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (2.2.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.13/dist-packages (from griffecli==2.2.0->griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama_index) (3.0.3)

# %%
pip install llama-index-readers-file
# Out:
# Collecting llama-index-readers-file
#   Downloading llama_index_readers_file-0.6.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /usr/local/lib/python3.13/dist-packages (from llama-index-readers-file) (4.13.5)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.13/dist-packages (from llama-index-readers-file) (0.7.1)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-readers-file) (0.14.24)
# Requirement already satisfied: pandas<3,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-readers-file) (2.2.3)
# Collecting pypdf<7,>=6.1.3 (from llama-index-readers-file)
#   Downloading pypdf-6.16.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file) (4.16.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (3.14.3)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.5.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2025.3.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.23.3)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (3.6.1)
# Requirement already satisfied: nltk>=3.9.3 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (3.10.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.1.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (11.3.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (4.11.3)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.13.4)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.32.4)
# Requirement already satisfied: setuptools>=80.9.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (84.0.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (9.1.4)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.14.0)
# Requirement already satisfied: tinytag>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.3.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (4.67.3)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.13/dist-packages (from llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas<3,>=2.0.0->llama-index-readers-file) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<3,>=2.0.0->llama-index-readers-file) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<3,>=2.0.0->llama-index-readers-file) (2026.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (1.24.5)
# Requirement already satisfied: griffe in /usr/local/lib/python3.13/dist-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in /usr/local/lib/python3.13/dist-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.5.0)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.13/dist-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.13/dist-packages (from nltk>=3.9.3->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2025.11.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=2.0.0->llama-index-readers-file) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2026.7.22)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (3.5.5)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.13/dist-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (3.26.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.16.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.13/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (26.3)
# Requirement already satisfied: griffecli==2.2.0 in /usr/local/lib/python3.13/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.2.0)
# Requirement already satisfied: griffelib==2.2.0 in /usr/local/lib/python3.13/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (2.2.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.13/dist-packages (from griffecli==2.2.0->griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-readers-file) (3.0.3)
# Downloading llama_index_readers_file-0.6.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.5 MB/s eta 0:00:00
# Downloading pypdf-6.16.2-py3-none-any.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.1/385.1 kB 10.6 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Installing collected packages: striprtf, pypdf, llama-index-readers-file
# Successfully installed llama-index-readers-file-0.6.0 pypdf-6.16.2 striprtf-0.0.26

# %%
import openai
from google.colab import userdata

# Retrieve the OpenAI API key from Google Colab secrets
openai.api_key = userdata.get('openai')

# %%
import os
import shutil # Import shutil to move files
import glob # Import glob to find files
from llama_index.core import SimpleDirectoryReader
from llama_index.readers.file import PDFReader # Corrected import path

# Create the data_new directory if it doesn't exist.
os.makedirs("data_new", exist_ok=True)

# Move existing PDF files from /content/ to data_new/
# This ensures that SimpleDirectoryReader can find them.
content_pdf_files = glob.glob("/content/*.pdf")
if content_pdf_files:
    print("Moving PDF files to 'data_new' directory...")
    for pdf_file_path in content_pdf_files:
        try:
            # Get just the filename from the path
            file_name = os.path.basename(pdf_file_path)
            destination_path = os.path.join("data_new", file_name)
            # Only move if it's not already in data_new (to prevent errors on re-run)
            if not os.path.exists(destination_path):
                shutil.move(pdf_file_path, destination_path)
                print(f"Moved: {file_name} to data_new/")
            else:
                print(f"File already exists in data_new: {file_name}, skipping move.")
        except Exception as e:
            print(f"Error moving file {pdf_file_path}: {e}")
else:
    print("No PDF files found in /content/ to move to 'data_new'.")

documents = SimpleDirectoryReader(
    input_dir="data_new",
    required_exts=[".pdf"],
    file_extractor={".pdf": PDFReader()}
).load_data()

print(f"Number of documents loaded: {len(documents)}")

if documents:
    print("First 1000 characters of the first document:")
    print(documents[0].text[:1000])
else:
    print("No PDF documents found in 'data_new' directory. Please upload your PDF files.")
# Out:
# Moving PDF files to 'data_new' directory...
# Moved: 1774547764701-7210b8fa-4738-46e7-8106-fe7929a010a0__community_file.pdf to data_new/
# Moved: 1774547734740-f6a2eed1-eb34-43d8-a679-e7c81688a123__community_file.pdf to data_new/
# Moved: 1774547764678-c8eb32b6-ae1b-40de-b4c3-cc9ac577d968__community_file.pdf to data_new/
# Moved: 1774547705170-8863c135-481a-4ff6-8c86-6da3be2245f0__community_file.pdf to data_new/
# Number of documents loaded: 9
# First 1000 characters of the first document:
# DDS Employee Handbook (Synthetic) v1
# Effective date: March 03, 2026  Dubai (GST)
# Note: This document is a synthetic, training-friendly employee handbook for demos, onboarding
# simulations, and HR-policy chatbot prototypes. It is not legal advice and must be reviewed by qualified
# counsel before any real-world use.
# 1. Welcome to Decoding Data Science (DDS)
# DDS is a Dubai-based academy, consulting practice, and community focused on data science, AI, and
# applied generative AI. We operate with a global mindset and a high trust culture—shipping practical
# outcomes while supporting each other.
# This handbook explains workplace expectations, benefits, and policies. If any local law conflicts with
# this handbook, applicable law prevails.
# 2. Company Values & Ways of Working
#  Build with clarity: define the user, problem, inputs/outputs, and definition of done.
#  Bias for action: ship small, iterate fast, measure outcomes.
#  Respect and inclusion: disagreement is allowed; disrespect is not.
#  Data i

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
documents = SimpleDirectoryReader("data_new").load_data()
index = VectorStoreIndex.from_documents(documents=documents)
query_engine = index.as_query_engine()
response = query_engine.query("how to take sick leave?")
print(response)
# Out:
# Inform your manager as soon as possible. If you will be absent for 2+ consecutive workdays, you may be asked to provide a medical certificate (as allowed by contract/law). Focus on recovery first.

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding

# Configure LLM, Embedding, and Chunk Size
Settings.llm = OpenAI(model="gpt-4o-mini", temperature=0.2)
Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-large")
Settings.chunk_size = 600
Settings.chunk_overlap = 200

# Define a system prompt
system_prompt = '''

You are Ayesha, the Decoding Data Science (DDS) Enterprise HR Chatbot. Your objective is to interact politely and professionally with employees, answering only HR-related questions. Use only information directly from the 4 connected HR documents to provide your answers. Always provide an explicit citation indicating the document source for every answer. Do not offer information or suggestions beyond what is present in these documents.

If the requested information cannot be found in the connected documents, politely instruct the user to email connect@decodingdatascience.com for further assistance. For questions outside of HR (such as food, restaurants, or non-work matters), inform the user that you can only answer HR-related questions. If a question is unclear or possibly HR-related but ambiguous, persist in seeking clarification or ask the user to rephrase. Never attempt to answer non-HR, personal, or unrelated questions.

- Remain polite and professional in all interactions.
- Respond exclusively to HR-related topics (e.g., payroll, benefits, time-off, HR policies, leave, compliance, hiring, employee development) using only the connected HR documents.
- Always include an explicit citation to the relevant document(s) for every answer.
- If a question is off-topic, state that you can only address HR questions.
- If you are unsure whether the question is HR-related, politely ask for clarification or rephrasing.
- For HR-related questions where the answer is not in the connected documents, kindly direct the user to email connect@decodingdatascience.com.
- Use a friendly and formal tone.
- Always persist in seeking clarification for ambiguous or insufficiently clear questions before providing an answer or deferring.

**Output Format:**
Respond in short, clear paragraphs (2-4 sentences). Do not use markdown or code blocks. Every answer must include the citation showing which document(s) the information is sourced from.

# Steps

1. Determine if the question is clearly HR-related.
2. If not HR-related, politely inform the user of your scope concerning only HR queries.
3. If the question is ambiguous or lacks clarity, persistently request clarification or rephrasing.
4. For HR questions, search the connected 4 HR documents.
    - If the answer is found, provide it with an explicit citation (e.g., "Document 2: Leave Policy, Section 3").
    - If the answer is not found in the documents, politely request the user to email connect@decodingdatascience.com for more assistance.

# Output Format

Respond in prose (2-4 clear sentences), including an explicit citation for every answer (e.g., "Source: Document 2, Leave Policy"). Do not use markdown or code blocks.

# Examples

**Example 1**
Input: What is the process for applying for maternity leave?
Output: Thank you for your question regarding maternity leave. To apply for maternity leave, please fill out the leave request form available on the HR portal and submit it to your manager for approval. Source: Document 2, Leave Policy.

**Example 2**
Input: Where is the best place to get lunch nearby?
Output: I can only assist with HR-related questions. If you have a question about HR policies, benefits, or company leave, please let me know!

**Example 3**
Input: Can you tell me about the company gym facilities?
Output: I am here to help with HR-related queries only. If your question relates to your employment, benefits, or HR policies, please clarify or rephrase your question.

**Example 4**
Input: How do I update my emergency contact information?
Output: You can update your emergency contact information by logging into the HR portal and editing your profile details. Source: Document 4, Employee Handbook.

**Example 5**
Input: How can I apply for a sabbatical leave?
Output: I am sorry, but I could not find information regarding sabbatical leave in our HR documents. For further assistance, please email connect@decodingdatascience.com.

**Important Instructions Reminder:**
- Answer HR questions strictly from the 4 connected documents and always provide a citation.
- For topics not covered in the documents, direct users to email connect@decodingdatascience.com.
- For off-topic or unclear queries, request clarification or state your HR-only scope.
- Remain friendly, professional, and persistent in seeking clarification when needed.


'''

documents = SimpleDirectoryReader("data_new").load_data()

index = VectorStoreIndex.from_documents(documents=documents)

# Configure query engine with system prompt
query_engine = index.as_query_engine(system_prompt=system_prompt)

response = query_engine.query("What are DDS standard office hours in Dubai?")
print(response)
# Out:
# The standard office hours for DDS in Dubai are from 9:00 AM to 6:00 PM, Monday to Friday.

# %%
documents
# Out:
# [Document(id_='2c5f8d88-e3df-4c31-a574-f8cafacf9377', embedding=None, metadata={'page_label': '1', 'file_name': '1774547705170-8863c135-481a-4ff6-8c86-6da3be2245f0__community_file.pdf', 'file_path': '/content/data_new/1774547705170-8863c135-481a-4ff6-8c86-6da3be2245f0__community_file.pdf', 'file_type': 'application/pdf', 'file_size': 9665, 'creation_date': '2026-08-27', 'last_modified_date': '2026-08-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS Employee Handbook (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\nNote: This document is a synthetic, training-friendly employee handbook for demos, onboarding\nsimulations, and HR-policy chatbot prototypes. It is not legal advice and must be reviewed by qualified\ncounsel before any real-world use.\n1. Welcome to Decoding Data Science (DDS)\nDDS is a Dubai-based academy, consulting practice, and community focused on data science, AI, and\napplied generative AI. We operate with a global mindset and a high trust culture—shipping practical\noutcomes while supporting each other.\nThis handbook explains workplace expectations, benefits, and policies. If any local law conflicts with\nthis handbook, applicable law prevails.\n2. Company Values & Ways of Working\n\x7f Build with clarity: define the user, problem, inputs/outputs, and definition of done.\n\x7f Bias for action: ship small, iterate fast, measure outcomes.\n\x7f Respect and inclusion: disagreement is allowed; disrespect is not.\n\x7f Data integrity: be precise with claims; cite sources; protect confidential information.\n\x7f Learning culture: continuous improvement is part of the job.\n3. Employment Classification (Synthetic Example)\nDDS may engage team members as:\n\x7f Full-time employees (UAE employment contract).\n\x7f Part-time employees (limited hours as per contract).\n\x7f Contractors / freelancers (service agreement).\nYour offer letter/contract defines your classification, compensation terms, notice periods, and\nbenefits.\n4. Equal Opportunity, Anti-Discrimination & Anti-Harassment\nDDS is committed to a workplace free from discrimination and harassment. We do not tolerate harassment\nbased on protected characteristics.\n\x7f Report concerns to HR or a designated People Partner.\n\x7f Reports are handled confidentially to the extent possible.\n\x7f Retaliation against anyone raising a concern in good faith is prohibited.\n\x7f Investigations may include interviews, review of communications, and documented outcomes.\n5. Code of Conduct\nAll team members are expected to:\n\x7f Act professionally with colleagues, partners, and learners.\n\x7f Avoid conflicts of interest; disclose them promptly.\n\x7f Use company resources responsibly.\n\x7f Follow lawful and ethical practices when using AI systems (no plagiarism, no misuse of data).\n\x7f Respect intellectual property and licensing obligations.\n6. Working Hours & Attendance (Hybrid/Global Teams)\n\x7f Standard office hours (Dubai): 9:00–18:00, Monday–Friday.\nPage 1\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='27bdf36b-77d2-4a18-892c-6e0438491887', embedding=None, metadata={'page_label': '2', 'file_name': '1774547705170-8863c135-481a-4ff6-8c86-6da3be2245f0__community_file.pdf', 'file_path': '/content/data_new/1774547705170-8863c135-481a-4ff6-8c86-6da3be2245f0__community_file.pdf', 'file_type': 'application/pdf', 'file_size': 9665, 'creation_date': '2026-08-27', 'last_modified_date': '2026-08-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="DDS Employee Handbook (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\n\x7f Teams operating across time zones set 'core collaboration hours' (e.g., 12:00–16:00 GST) where\n  meetings may be scheduled.\n\x7f Outside core hours, work is flexible and outcome-based.\nAttendance expectations:\n\x7f Join scheduled meetings on time; inform the host if running late.\n\x7f If unexpectedly absent, notify your manager as soon as possible.\n\x7f Repeated unexplained absences may trigger a performance/disciplinary process.\n7. Breaks, Overtime & Time Off in Lieu (TOIL)\n\x7f Breaks should be taken in a way that supports health and productivity.\n\x7f For roles where overtime may occur (events, launches), managers may approve TOIL.\n\x7f Overtime/TOIL rules depend on local contract terms and applicable labor law.\n\x7f Log time in the agreed tracker when required by your team.\n8. Probation & Confirmation\nNew hires may be placed on a probation period as stated in the employment contract.\n\x7f During probation, performance expectations are set clearly with weekly check-ins.\n\x7f Confirmation occurs after successful completion of probation and required documentation.\n9. Performance Management\nDDS uses an outcomes-first approach:\n\x7f Quarterly goals (OKRs or milestone plans) aligned to the business roadmap.\n\x7f Regular 1:1 check-ins with managers.\n\x7f Feedback is specific, timely, and actionable.\nIf performance concerns arise:\n\x7f Step 1: Clarify expectations and provide support.\n\x7f Step 2: Document a performance improvement plan (PIP) with measurable milestones.\n\x7f Step 3: Review outcomes; further action may include role change or termination (per contract/law).\n10. Learning, Training & Development\nDDS invests in learning because it is core to our mission.\n\x7f Team members may receive access to internal courses, recordings, and selected external trainings.\n\x7f Sharing learnings is encouraged: short notes, demos, internal talks.\n\x7f Training time is scheduled with managers to protect delivery commitments.\n11. Confidentiality & Intellectual Property\nConfidential information includes (but is not limited to): learner data, pricing, partnerships, product\nroadmaps, internal docs, and source code.\n\x7f Do not share confidential information externally without approval.\n\x7f Work created in the course of employment may be owned by DDS as per contract terms.\n\x7f Respect third-party IP: do not copy copyrighted content into DDS assets without proper licensing.\n12. Data Protection & Privacy (Operational Expectations)\nDDS handles personal and business data responsibly.\nPage 2\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='e1f11283-96b0-40f7-baa8-fd1d7ff84cd6', embedding=None, metadata={'page_label': '3', 'file_name': '1774547705170-8863c135-481a-4ff6-8c86-6da3be2245f0__community_file.pdf', 'file_path': '/content/data_new/1774547705170-8863c135-481a-4ff6-8c86-6da3be2245f0__community_file.pdf', 'file_type': 'application/pdf', 'file_size': 9665, 'creation_date': '2026-08-27', 'last_modified_date': '2026-08-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="DDS Employee Handbook (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\n\x7f Only collect data that is necessary.\n\x7f Store data only in approved systems.\n\x7f Apply least-privilege access.\n\x7f Never export learner/employee data to personal devices or unapproved tools.\n\x7f AI tools: do not paste confidential data into public chatbots unless an approved enterprise\n  environment is in place.\nReport suspected data incidents immediately to your manager and the security/IT owner.\n13. Acceptable Use of AI Tools\nAI is part of our workflows, but must be used safely:\n\x7f Verify outputs; do not treat AI as a source of truth.\n\x7f Cite sources when producing research or educational content.\n\x7f Avoid generating deceptive content or misrepresenting AI-generated work as human work when it matters.\n\x7f Use approved model providers and enterprise settings when handling sensitive data.\n\x7f For client work, follow client contractual constraints on data/model usage.\n14. Communications, Social Media & Public Representation\nDDS has a strong public presence; how we communicate matters.\n\x7f Be respectful and factual in public channels.\n\x7f Do not announce partnerships, pricing, or internal matters without approval.\n\x7f If you speak as an individual, clarify that opinions are your own.\n\x7f For press/media requests, route to the designated spokesperson.\n15. Workplace Safety, Wellbeing & Emergency Procedures\n\x7f Follow building safety instructions in offices/event venues.\n\x7f Report hazards promptly.\n\x7f In emergencies, prioritize people safety and follow local authorities' instructions.\n\x7f DDS supports wellbeing through reasonable workloads, clear planning, and respectful collaboration.\n16. Disciplinary Process (Simplified)\nDepending on severity, DDS may use progressive steps:\n\x7f Coaching and verbal warning.\n\x7f Written warning with clear expectations.\n\x7f Final warning or performance plan.\n\x7f Termination (for severe misconduct or repeated issues).\nGross misconduct examples (non-exhaustive): harassment, theft, serious data breach, violence, fraud, or\nwillful policy violation.\n17. Grievance & Reporting Channels\nIf you have a complaint or concern:\n\x7f Step 1: Raise it with your manager (if appropriate).\n\x7f Step 2: If not resolved or not appropriate, contact HR/People Partner.\n\x7f Step 3: Escalate to leadership if needed.\nDDS aims to respond quickly, document actions taken, and protect confidentiality.\nPage 3\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='55301f6b-b4f4-4e52-a7ea-1827e2b8038f', embedding=None, metadata={'page_label': '4', 'file_name': '1774547705170-8863c135-481a-4ff6-8c86-6da3be2245f0__community_file.pdf', 'file_path': '/content/data_new/1774547705170-8863c135-481a-4ff6-8c86-6da3be2245f0__community_file.pdf', 'file_type': 'application/pdf', 'file_size': 9665, 'creation_date': '2026-08-27', 'last_modified_date': '2026-08-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS Employee Handbook (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\n18. Policy Governance & Updates\nThis handbook may be updated as DDS evolves.\n\x7f HR communicates material changes.\n\x7f The latest version lives in the internal knowledge base.\n\x7f Your contract and local labor law remain the governing documents where applicable.\nPage 4\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='320d8db3-b963-417a-8ca7-7e2d0de8b44b', embedding=None, metadata={'page_label': '1', 'file_name': '1774547734740-f6a2eed1-eb34-43d8-a679-e7c81688a123__community_file.pdf', 'file_path': '/content/data_new/1774547734740-f6a2eed1-eb34-43d8-a679-e7c81688a123__community_file.pdf', 'file_type': 'application/pdf', 'file_size': 5066, 'creation_date': '2026-08-27', 'last_modified_date': '2026-08-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS Leave Policy (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\nNote: This document is a synthetic, training-friendly employee handbook for demos, onboarding\nsimulations, and HR-policy chatbot prototypes. It is not legal advice and must be reviewed by qualified\ncounsel before any real-world use.\n1. Leave Policy Overview\nDDS provides leave benefits to support rest, health, and personal responsibilities. Specific\nentitlements depend on contract type and applicable law.\nPrinciples:\n\x7f Plan early to support team coverage.\n\x7f Use the leave system for tracking and approvals.\n\x7f Be transparent; avoid last-minute leave where possible.\n2. Annual Leave (Example Policy)\n\x7f Entitlement: as per employment contract (commonly 22–30 working days per year for full-time roles).\n\x7f Accrual: monthly accrual may apply depending on payroll setup.\n\x7f Request window: submit at least 7–14 days in advance; longer for trips.\n\x7f Approval: manager approval required; HR may review for compliance.\n\x7f Peak periods: events/launch windows may restrict approvals; plan accordingly.\n\x7f Carry-forward: limited carry-forward may be allowed; unused leave may expire per policy/contract.\n3. Sick Leave (Example Policy)\n\x7f Use sick leave when you are unwell and unable to work.\n\x7f Notify your manager as soon as possible.\n\x7f A medical certificate may be required for absences of 2+ consecutive workdays or if patterns suggest\n  misuse.\n\x7f If you can work partially (e.g., reduced hours), agree this with your manager—health comes first.\n4. Public Holidays (UAE Context)\n\x7f DDS observes applicable UAE public holidays for Dubai-based employees.\n\x7f For cross-border teams, local public holidays may apply based on contract location.\n\x7f HR publishes a holiday calendar annually; managers coordinate coverage for time-sensitive operations.\n5. Compassionate/Bereavement Leave (Example Policy)\n\x7f Provided in the event of the death of an immediate family member.\n\x7f Notify your manager and HR.\n\x7f Duration: as per contract/policy; additional unpaid leave may be approved as needed.\n6. Maternity / Paternity / Parental Leave (Example Policy)\n\x7f Leave entitlements follow UAE labor requirements and contract terms.\n\x7f HR will provide case-specific guidance confidentially.\n\x7f Managers must support a respectful transition plan before and after leave.\n7. Unpaid Leave\n\x7f Requires manager + HR approval.\n\x7f Approval is case-by-case based on business needs and employment terms.\n\x7f Unpaid leave may affect payroll, benefits, and visa arrangements depending on status.\nPage 1\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='2ad3cc1e-8e4a-4ab7-a6d4-b077f103a381', embedding=None, metadata={'page_label': '2', 'file_name': '1774547734740-f6a2eed1-eb34-43d8-a679-e7c81688a123__community_file.pdf', 'file_path': '/content/data_new/1774547734740-f6a2eed1-eb34-43d8-a679-e7c81688a123__community_file.pdf', 'file_type': 'application/pdf', 'file_size': 5066, 'creation_date': '2026-08-27', 'last_modified_date': '2026-08-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS Leave Policy (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\n8. Religious Observances & Ramadan Adjustments\nDDS respects religious practices.\n\x7f During Ramadan, working hours may be reduced as per UAE regulation for applicable employees.\n\x7f Teams coordinate meeting schedules to be considerate of fasting and prayer times.\n\x7f Flexibility can be arranged with the manager where role allows.\n9. Leave Request & Approval Workflow\n\x7f Submit request in the leave system (or approved tracker).\n\x7f Add coverage plan: what will be delivered, who will cover, and key deadlines.\n\x7f Notify stakeholders for client-facing commitments.\n\x7f Wait for approval before booking non-refundable travel (recommended).\n\x7f For emergency leave, notify immediately and submit retroactively within 24–48 hours.\n10. Misuse, Fraud & Compliance\nMisuse of leave (e.g., misrepresenting sickness) may lead to disciplinary action.\nDDS may request documentation where reasonable and lawful.\nPage 2\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='dc047a10-c3cc-43b2-813a-750a7bd2dc0b', embedding=None, metadata={'page_label': '1', 'file_name': '1774547764678-c8eb32b6-ae1b-40de-b4c3-cc9ac577d968__community_file.pdf', 'file_path': '/content/data_new/1774547764678-c8eb32b6-ae1b-40de-b4c3-cc9ac577d968__community_file.pdf', 'file_type': 'application/pdf', 'file_size': 4707, 'creation_date': '2026-08-27', 'last_modified_date': '2026-08-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS Remote Work Policy (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\nNote: This document is a synthetic, training-friendly employee handbook for demos, onboarding\nsimulations, and HR-policy chatbot prototypes. It is not legal advice and must be reviewed by qualified\ncounsel before any real-world use.\n1. Remote Work Philosophy\nDDS supports remote and hybrid work because our team and learners are global. Remote work is a privilege\ntied to trust, outcomes, and security.\nRemote success requires:\n\x7f Clear goals and ownership.\n\x7f High-quality written communication.\n\x7f Reliable availability during core collaboration hours.\n2. Eligibility & Approval\nRemote work depends on role suitability, performance, and operational needs.\n\x7f Approval is granted by the line manager.\n\x7f HR may define role-based constraints (e.g., event roles require onsite presence).\n\x7f DDS may revoke remote status if outcomes or security requirements are not met.\n3. Working Hours & Availability\n\x7f Teams define core hours where everyone is expected to be reachable.\n\x7f Outside core hours, work is flexible as long as deliverables are met.\n\x7f Keep calendars accurate; update status (busy/OOO) and response expectations.\n4. Home Office Setup (Minimum Standard)\n\x7f Stable internet connection and a quiet workspace.\n\x7f Headset for calls; webcam as required for meetings.\n\x7f Ability to protect confidential information (no shoulder-surfing, lock screen).\n\x7f Use approved storage and collaboration tools.\n5. Security & Data Handling\n\x7f Use company-approved devices when provided.\n\x7f Enable strong authentication (MFA) on all work accounts.\n\x7f Keep devices updated with security patches.\n\x7f Do not store DDS data on personal cloud drives or unapproved services.\n\x7f Report lost devices or suspected compromise immediately.\nAI tools:\n\x7f Do not paste confidential documents into public AI tools.\n\x7f Use approved enterprise environments for sensitive data when available.\n6. Meetings, Documentation & Asynchronous Work\nDDS prefers async-first documentation:\n\x7f Write decisions and action items in shared docs.\n\x7f Record key meetings when appropriate (with consent).\n\x7f Use clear templates for project updates (status, risks, next steps).\n\x7f Reduce unnecessary meetings; default to written updates when possible.\nPage 1\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='dec746c6-1394-46a9-a05d-ba9b10bef0b3', embedding=None, metadata={'page_label': '2', 'file_name': '1774547764678-c8eb32b6-ae1b-40de-b4c3-cc9ac577d968__community_file.pdf', 'file_path': '/content/data_new/1774547764678-c8eb32b6-ae1b-40de-b4c3-cc9ac577d968__community_file.pdf', 'file_type': 'application/pdf', 'file_size': 4707, 'creation_date': '2026-08-27', 'last_modified_date': '2026-08-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS Remote Work Policy (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\n7. Travel, Working From Abroad (Example Rules)\n\x7f Working from outside your usual country may require manager approval.\n\x7f Consider visa, tax, and data access restrictions.\n\x7f Maintain secure connectivity; use VPN if required.\n\x7f Time zone shifts must not disrupt critical commitments.\n8. Equipment & Expenses (Example Policy)\n\x7f If DDS provides equipment, it must be used for work and returned upon exit.\n\x7f Expense reimbursement (internet/tools) depends on your contract and role.\n\x7f All expenses require receipts and prior approval where applicable.\nPage 2\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='42d00f2e-d8d5-4acd-be1b-945e43f72e35', embedding=None, metadata={'page_label': '1', 'file_name': '1774547764701-7210b8fa-4738-46e7-8106-fe7929a010a0__community_file.pdf', 'file_path': '/content/data_new/1774547764701-7210b8fa-4738-46e7-8106-fe7929a010a0__community_file.pdf', 'file_type': 'application/pdf', 'file_size': 2933, 'creation_date': '2026-08-27', 'last_modified_date': '2026-08-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS HR FAQ (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\nNote: This document is a synthetic, training-friendly employee handbook for demos, onboarding\nsimulations, and HR-policy chatbot prototypes. It is not legal advice and must be reviewed by qualified\ncounsel before any real-world use.\nHow do I request leave?\nSubmit a request in the leave system (or the approved tracker) with dates and a short coverage plan.\nNotify your manager and any stakeholders affected by deadlines.\nTypical approval time: 1–3 business days (may vary during peak periods).\nWhat should I do if I’m sick?\nInform your manager as soon as possible. If you will be absent for 2+ consecutive workdays, you may be\nasked to provide a medical certificate (as allowed by contract/law). Focus on recovery first.\nCan I work remotely full-time?\nIt depends on your role, performance, and operational needs. Discuss with your manager. HR may provide\nrole-based guidelines.\nWhat tools should I use for work?\nUse DDS-approved tools for email, documents, chat, project tracking, and file storage. If you’re unsure,\nask your manager or IT owner.\nHow do I report harassment or discrimination?\nYou can contact HR/People Partner directly, or raise it with your manager if appropriate.\nConfidentiality is respected, and retaliation is prohibited.\nWhere do I ask case-specific questions?\nFor personal or case-specific issues (leave exceptions, conflicts, concerns), contact HR directly. DDS\nwill handle your request discreetly.\nPage 1\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]

# %%
import time
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader

# Start timer
start_time = time.time()

# Load and index documents
documents = SimpleDirectoryReader("data_new").load_data()
index = VectorStoreIndex.from_documents(documents=documents)

# Query the index
query_engine = index.as_query_engine()
response = query_engine.query("What are DDS standard office hours in Dubai?")
print(response)

# End timer and print duration
end_time = time.time()
print(f"\nExecution Time: {end_time - start_time:.2f} seconds")
# Out:
# The standard office hours for DDS in Dubai are from 9:00 AM to 6:00 PM, Monday to Friday.
#
# Execution Time: 2.50 seconds

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.13/dist-packages (6.24.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (4.14.2)
# Requirement already satisfied: audioop-lts<=0.2.2 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.141.1)
# Requirement already satisfied: gradio-client==2.6.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (2.6.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.4.1)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.16.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (1.27.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (3.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from gradio) (26.3)
# Requirement already satisfied: pandas<4.0,>=1.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (2.13.4)
# Requirement already satisfied: pydub<1.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.0.32)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.13/dist-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from gradio) (1.6.0)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.14.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.27.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (4.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.13/dist-packages (from gradio) (0.52.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.13/dist-packages (from gradio-client==2.6.0->gradio) (2025.3.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0,>=3.0->gradio) (3.18)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.16.0->gradio) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.16.0->gradio) (3.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.16.0->gradio) (1.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=1.16.0->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<4.0,>=1.0->gradio) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<=3.0,>=2.0->gradio) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import gradio as gr
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import Settings

# Configure LLM, Embedding, and Chunk Size
Settings.llm = OpenAI(model="gpt-4o-mini", temperature=0.2)
Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-large")
Settings.chunk_size = 600
Settings.chunk_overlap = 200

# Load data and build the index
documents = SimpleDirectoryReader("data_new").load_data()
index = VectorStoreIndex.from_documents(documents=documents)
query_engine = index.as_query_engine()

# Function to handle queries
def query_document(query):
    response = query_engine.query(query)
    return str(response)

# Example HR questions
examples = [
    "How do I apply for sick leave?",
    "What are the company's remote work policies?",
    "What benefits are available to employees?",
    "How can I update my personal information?"
]

# Define a dark theme (Monochrome is already dark)
dark_theme = gr.themes.Monochrome()

# Combine title and description into a single Markdown string for the description parameter (logo removed)
description_with_logo = """
<div style='text-align: center; margin-bottom: 20px;'>
    <p style='text-align: center;'>Ask questions about the documents loaded into the system.</p>
</div>
"""

# Gradio interface with enhancements
interface = gr.Interface(
    fn=query_document,
    inputs=gr.Textbox(label="Enter your query", placeholder="Type your question here..."),
    outputs=gr.Textbox(label="Response"),
    title="PeoplePulse AI", # Keep a plain text title for the browser tab/Gradio UI header
    description=description_with_logo, # Use the combined HTML for logo and description
    examples=examples # Add example questions
)

# Launch the Gradio app with the theme parameter in launch()
if __name__ == "__main__":
    interface.launch(theme=dark_theme)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://d2179f9b5f35db25f6.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d2179f9b5f35db25f6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import os
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine

from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
)

# check if storage already exists
PERSIST_DIR = "./storage"
if not os.path.exists(PERSIST_DIR):
    # load the documents and create the index
    documents = SimpleDirectoryReader("data_new").load_data()
    index = VectorStoreIndex.from_documents(documents)
    # store it for later
    index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    # load the existing index
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
    index = load_index_from_storage(storage_context)

# Either way we can now query the index
query_engine = index.as_query_engine()

retriever = VectorIndexRetriever(index=index, similarity_top_k=3)

query_engine = RetrieverQueryEngine(retriever=retriever)

response = query_engine.query("What are DDS standard office hours in Dubai?")
print(response)
# Out:
# The standard office hours for DDS in Dubai are from 9:00 AM to 6:00 PM, Monday to Friday.

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.readers.file import PDFReader

documents = SimpleDirectoryReader(
    input_dir="data_new",
    required_exts=[".pdf"],
    file_extractor={".pdf": PDFReader()}
).load_data()

print(len(documents))
print(documents[0].text[:1000])
# Out:
# 13
# DDS Employee Handbook (Synthetic) v1
# Effective date: March 03, 2026  Dubai (GST)
# Note: This document is a synthetic, training-friendly employee handbook for demos, onboarding
# simulations, and HR-policy chatbot prototypes. It is not legal advice and must be reviewed by qualified
# counsel before any real-world use.
# 1. Welcome to Decoding Data Science (DDS)
# DDS is a Dubai-based academy, consulting practice, and community focused on data science, AI, and
# applied generative AI. We operate with a global mindset and a high trust culture—shipping practical
# outcomes while supporting each other.
# This handbook explains workplace expectations, benefits, and policies. If any local law conflicts with
# this handbook, applicable law prevails.
# 2. Company Values & Ways of Working
#  Build with clarity: define the user, problem, inputs/outputs, and definition of done.
#  Bias for action: ship small, iterate fast, measure outcomes.
#  Respect and inclusion: disagreement is allowed; disrespect is not.
#  Data i

# %%
import os
import time
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine

from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
)

# Start timer for index setup
start_time = time.time()

# check if storage already exists
PERSIST_DIR = "./storage"
if not os.path.exists(PERSIST_DIR):
    # load the documents and create the index
    documents = SimpleDirectoryReader("data_new").load_data()
    index = VectorStoreIndex.from_documents(documents)
    # store it for later
    index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    # load the existing index
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
    index = load_index_from_storage(storage_context)

setup_duration = time.time() - start_time
print(f"Index setup time: {setup_duration:.2f} seconds")

# Start timer for query
query_start_time = time.time()

# Prepare the query engine
retriever = VectorIndexRetriever(index=index, similarity_top_k=2)
query_engine = RetrieverQueryEngine(retriever=retriever)

# Execute query
response = query_engine.query("Who all mentioned in the doc?")
print(response)

query_duration = time.time() - query_start_time
print(f"Query time: {query_duration:.2f} seconds")
# Out:
# Index setup time: 0.38 seconds
# The document mentions team members, colleagues, partners, learners, managers, HR or People Partners, leadership, and a designated spokesperson.
# Query time: 0.93 seconds

# %%
import os
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine

from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
)

import time
start_time = time.time()
query_engine = index.as_query_engine()

retriever = VectorIndexRetriever(index=index, similarity_top_k=2)

query_engine = RetrieverQueryEngine(retriever=retriever)

response = query_engine.query("What are DDS standard office hours in Dubai??")
print(response)


end_time = time.time()  # Record end time
execution_time = end_time - start_time  # Calculate execution time
print(f"Execution time: {execution_time} seconds")
# Out:
# The standard office hours for DDS in Dubai are from 9:00 AM to 6:00 PM, Monday to Friday.
# Execution time: 0.9687755107879639 seconds

# %%
# !pip show llama-index-readers-file
# Out:
# Name: llama-index-readers-file
# Version: 0.6.0
# Summary: llama-index readers file integration
# Home-page:
# Author:
# Author-email: Your Name <you@example.com>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: beautifulsoup4, defusedxml, llama-index-core, pandas, pypdf, striprtf
# Required-by:
